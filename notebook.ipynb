# %%
# Package installs
# %pip -q install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the data
file_path = 'Meteorite_Landings.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seaborn style
sns.set(style='whitegrid')

# Create a scatter plot of the meteorite landings
plt.figure(figsize=(12, 8))
plt.scatter(data['reclong'], data['reclat'], alpha=0.5, s=10)
plt.title('Distribution of Meteorite Landings', fontsize=16)
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Creating a scatter plot with a color gradient based on mass
scatter = plt.scatter(data['reclong'], data['reclat'], c=data['mass (g)'], cmap='viridis', alpha=0.5, s=10)

# Adding a colorbar
plt.colorbar(scatter, label='Mass (g)')

plt.title('Scatter Chart of Meteorite Landings by Mass', fontsize=16)
plt.xlabel('Longitude', fontsize=14)
plt.ylabel('Latitude', fontsize=14)
plt.xlim([-180, 180])
plt.ylim([-90, 90])
plt.grid(True)
plt.show()
